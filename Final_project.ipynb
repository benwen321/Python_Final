# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\benja\Downloads\archive (3)\US_listed_companies.csv")
df.head()
# Out:
#    company_number                      primary_industry  \
# 0               1      Life Sciences Tools and Services
# 1               2  Internet and Direct Marketing Retail
# 2               3                   Healthcare Services
# 3               4                     Tobacco Producers
# 4               5                  Application Software
#
#                        secondary_industry  \
# 0                              Healthcare
# 1                                Consumer
# 2                              Healthcare
# 3                                Consumer
# 4  Technology, Media & Telecommunications
#
#                              sub_secondary_industry  dividend_payer  \
# 0  Pharmaceuticals, Biotechnology and Life Sciences               0
# 1                                            Retail               0
# 2                 Healthcare Providers and Services               0
# 3                                         Producers               0
# 4                            Information Technology               0
#
#      ebit_fy2019  ebit_fy2020  marketcap_decemb2019  MTBV_Dec2019  \
# 0     129.000000     -73224.0          7.332959e+06     17.455977
# 1    -993.385986          NaN                   NaN           NaN
# 2  -54113.000000     -71359.0                   NaN           NaN
# 3  -21704.111330          NaN          1.397766e+05      2.252614
# 4 -157577.000000    -169835.0          1.522811e+06      2.141035
#
#    totalreturn_percent_ytd_dec2020  dps_fy2020  dps_fy2019  \
# 0                            87.03         NaN         NaN
# 1                           -12.11         NaN         NaN
# 2                            97.05         NaN         NaN
# 3                           114.55         NaN         NaN
# 4                            70.15         NaN         NaN
#
#    day_close_price_dollars_december  change_in_earnings_by_marketcap_  \
# 0                             76.25                              -1.0
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                              1.10                               NaN
# 4                             23.99                              -0.8
#
#    total_equity_fy2019
# 0           420083.000
# 1             -795.954
# 2           218457.000
# 3            62050.822
# 4           711250.000

# %%
def most_change(dataframe):
    industries = dataframe["primary_industry"].unique().tolist()
    industry_ebit_change = pd.DataFrame(columns=['Industry', 'ebit_change'])
    for index in industries: 
        industry_stats = pd.DataFrame(dataframe[dataframe["primary_industry"] == index])
        industry_stats = pd.DataFrame(industry_stats.dropna(subset=['change_in_earnings_by_marketcap_']))
        industry_stats = pd.DataFrame(industry_stats.sort_values(by=['change_in_earnings_by_marketcap_'], ascending=False))
        ebit_mean_change = industry_stats['change_in_earnings_by_marketcap_'].mean()
        ebit_change_df = pd.DataFrame({'Industry':[index],'ebit_change':[ebit_mean_change]})
        industry_ebit_change = industry_ebit_change.append(ebit_change_df)
    #print(index)
    #print(ebit_mean_change)
    industry_ebit_change = pd.DataFrame(industry_ebit_change.dropna(subset=['ebit_change']))
    industry_ebit_change = industry_ebit_change.sort_values("ebit_change")
    print("Industry that grew the most: " + str(industry_ebit_change.tail(1)))
    print("Industry that shrank the most: " + str(industry_ebit_change.head(1)))
    return industry_ebit_change

# %%
def general_economic_patterns(dataframe):
    mean_marketcap_change = dataframe["change_in_earnings_by_marketcap_"].mean()
    dividend_companies = pd.DataFrame(dataframe.dropna(subset=['dps_fy2019', 'dps_fy2020']))
    dividend_companies = dividend_companies[dividend_companies['dps_fy2019']>0.0]
    print(dividend_companies)
    dividend_change_df = pd.DataFrame(columns=['Industry', 'change_in_dividends'])
    for index,series in dividend_companies.iterrows():
        dividend_change = (index['dps_fy2020'] - index['dps_fy2019'])/index['dps_fy2019']
        dividend_change = pd.DataFrame({'Industry':[index['primary_industry']], 'change_in_dividends':[dividend_change]})
        dividend_change_df.append(dividend_change)
    print(dividend_change_df.head())

# %%
general_economic_patterns(df)
# Out:
#       company_number          primary_industry  \
# 6                  7  Industrial Conglomerates
# 9                 10                Publishing
# 10                11         Building Products
# 12                13         Building Products
# 13                14      Healthcare Equipment
# ...              ...                       ...
# 2723            2724          Systems Software
# 2727            2728     Machinery: Industrial
# 2733            2734               Restaurants
# 2739            2740      Healthcare Equipment
# 2742            2743           Pharmaceuticals
#
#                           secondary_industry  \
# 6                                Industrials
# 9     Technology, Media & Telecommunications
# 10                               Industrials
# 12                               Industrials
# 13                                Healthcare
# ...                                      ...
# 2723  Technology, Media & Telecommunications
# 2727                             Industrials
# 2733                                Consumer
# 2739                              Healthcare
# 2742                              Healthcare
#
#                                 sub_secondary_industry  dividend_payer  \
# 6                                        Capital Goods               1
# 9                                                Media               1
# 10                                       Capital Goods               1
# 12                                       Capital Goods               1
# 13                                Healthcare Equipment               1
# ...                                                ...             ...
# 2723                            Information Technology               1
# 2727                                     Capital Goods               1
# 2733                   Hotels, Restaurants and Leisure               1
# 2739                              Healthcare Equipment               1
# 2742  Pharmaceuticals, Biotechnology and Life Sciences               1
#
#       ebit_fy2019  ebit_fy2020  marketcap_decemb2019  MTBV_Dec2019  \
# 6       7136000.0    7072000.0           101450440.0     10.018807
# 9         13721.0          NaN               60527.5      1.048331
# 10       459700.0     441400.0             7770654.0      4.662019
# 12        68485.0      97473.0             2574141.5      8.872067
# 13      4823000.0    5553000.0           153608064.0      4.907449
# ...           ...          ...                   ...           ...
# 2723     -58945.0     247830.0                   NaN           NaN
# 2727     695000.0     491000.0            14188414.0      4.782074
# 2733    1931000.0    1762000.0            30467014.0           NaN
# 2739    1406200.0     930900.0            30786836.0      2.484252
# 2742    2097000.0    2301000.0            63038204.0     23.278510
#
#       totalreturn_percent_ytd_dec2020  dps_fy2020  dps_fy2019  \
# 6                                2.39        5.88       5.760
# 9                              -41.85        0.20       0.320
# 10                              17.25        0.98       0.900
# 12                              35.43        0.38       0.320
# 13                              26.78        1.53       1.320
# ...                               ...         ...         ...
# 2723                            55.63        0.50       0.800
# 2727                            29.59        1.04       0.960
# 2733                            10.79        1.91       1.730
# 2739                             2.50        0.96       0.960
# 2742                            24.82        0.80       0.656
#
#       day_close_price_dollars_december  change_in_earnings_by_marketcap_  \
# 6                               176.42                             -0.06
# 9                                 2.82                               NaN
# 10                               47.64                             -0.24
# 12                               49.41                              1.13
# 13                               86.86                              0.48
# ...                                ...                               ...
# 2723                               NaN                               NaN
# 2727                             78.79                             -1.44
# 2733                            100.73                             -0.55
# 2739                            149.68                             -1.54
# 2742                            132.35                              0.32
#
#       total_equity_fy2019
# 6              10126000.0
# 9                 57737.0
# 10              1666800.0
# 12               290140.0
# 13             31301000.0
# ...                   ...
# 2723             545100.0
# 2727            2967000.0
# 2733           -8016000.0
# 2739           12392800.0
# 2742            2708000.0
#
# [903 rows x 15 columns]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7728\3348483012.py in <module>
# ----> 1 general_economic_patterns(df)
#
# ~\AppData\Local\Temp\ipykernel_7728\3168376903.py in general_economic_patterns(dataframe)
#       6     dividend_change_df = pd.DataFrame(columns=['Industry', 'change_in_dividends'])
#       7     for index,series in dividend_companies.iterrows():
# ----> 8         dividend_change = (index['dps_fy2020'] - index['dps_fy2019'])/index['dps_fy2019']
#       9         dividend_change = pd.DataFrame({'Industry':[index['primary_industry']], 'change_in_dividends':[dividend_change]})
#      10         dividend_change_df.append(dividend_change)
#
# TypeError: 'int' object is not subscriptable

# %%
def
# Out:
#   File "C:\Users\benja\AppData\Local\Temp\ipykernel_7728\1885169875.py", line 1
#     def
#         ^
# SyntaxError: invalid syntax
